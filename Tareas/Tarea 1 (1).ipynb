# %% [markdown]
# # Tarea 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import matplotlib.colors as mcolors

# %% [markdown]
# ### Ejemplo 1

# %%
# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Color personalizado en hexadecimal
hex_color = "#0000FF"  # Azul

# Crear gráfica
plt.figure(figsize=(6, 4))
plt.plot(x, y, marker='o', color=hex_color, linewidth=2, label=f"Color {hex_color}")
plt.title("Gráfica con color hexadecimal personalizado")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# #### Ejemplo 2

# %%
def generate_random_hex_color():
    return "#{:06X}".format(random.randint(0, 0xFFFFFF))

# Generar 5 colores aleatorios
colors = [generate_random_hex_color() for _ in range(5)]

# Graficar como barras de colores
plt.figure(figsize=(8, 4))
for i, color in enumerate(colors):
    plt.bar(i, 1, color=color)
    plt.text(i, 1.05, color, ha='center', va='bottom', fontsize=10)
    
plt.xticks([])
plt.yticks([])
plt.title("5 Colores Aleatorios en Hexadecimal")
plt.xlim(-0.5, 4.5)
plt.ylim(0, 1.1)
plt.tight_layout()

# %% [markdown]
# Ejemplo de uso de codificacion hexadecimal del color , se quiere representar la distribución de temperatura en una placa usando colores, internamente, matplotlib traduce cada valor numérico a un código RGB/hex para generar la imagen.

# %%
temperatura = np.random.rand(10, 10) * 100  # Temperaturas entre 0 y 100 °C
plt.imshow(temperatura, cmap='inferno')     # Mapa de color inferno (RGB)
plt.colorbar(label="Temperatura (°C)")
plt.title("Distribución de temperatura")
plt.show()

# %% [markdown]
# ## Tarea 1
# Generar un mapa de color personalizado a partir de un color hexadecimal base
#
# ### Instrucciones:
# 1. Define un color base en formato hexadecimal, por ejemplo `#66ccff` (azul claro).
# 2. Genera con numpy una matriz de valores aleatorios entre 0 y 1 (por ejemplo de 10x10).
# 3. Completa la función `darken_color` , que cumpla las siguientes caracteristicas:
#    - Reciba un valor entre 0 y 1.
#    - Devuelva un color más oscuro que el color base, en función del valor recibido.
#      * A mayor valor, más oscuro el color.
# 5. Aplica tu función a cada valor para obtener una matriz de colores personalizados.
# 6. Muestra la matriz de colores como una imagen (`imshow` de matplotlib), sin usar colormaps predefinidos.
# 7. Bonus: agrega una barra de color personalizada o una leyenda.
#
# ### Requisitos:
# - Trabajar con el formato de color hexadecimal.
# - No usar cmap de Matplotlib (se construye a mano).
# - Usar `matplotlib.colors.to_rgb` y `matplotlib.colors.to_hex` puede ayudarte.

# %%
# Paso 1: color base
# Define el color base
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
base_hex = "#5D04D0"
base_rgb = np.array(mcolors.to_rgb(base_hex))
print(base_rgb)
print(base_rgb*2)
# Out:
# [0.36470588 0.01568627 0.81568627]
# [0.72941176 0.03137255 1.63137255]

# %% [markdown]
# Que hace la función `to_rgb`?

# %%
# Paso 2: generar datos, generamos una matriz de datos aleatorios
data = np.random.rand(10, 10)

# %%
print(data)
# Out:
# [[0.9273516  0.92182512 0.41284775 0.52253456 0.20772802 0.65150672
#   0.89148261 0.28943181 0.86406039 0.79003908]
#  [0.40851476 0.95082317 0.38720673 0.75000307 0.32821747 0.40249348
#   0.73289697 0.4756878  0.04816354 0.84166405]
#  [0.58268712 0.15686273 0.87549025 0.65896857 0.81187975 0.86178091
#   0.42887983 0.99862004 0.15212594 0.55108663]
#  [0.46763958 0.09088551 0.33521577 0.80820783 0.53672388 0.85379385
#   0.18732409 0.70610859 0.58014847 0.19923331]
#  [0.59226089 0.06506321 0.03525638 0.25314536 0.9894539  0.64794218
#   0.70278963 0.58165158 0.6361927  0.33685553]
#  [0.62893772 0.52930168 0.95808157 0.0811955  0.75491521 0.1190776
#   0.90069621 0.38280947 0.95772898 0.74856171]
#  [0.7933784  0.09777997 0.9349636  0.92206741 0.85671363 0.40377835
#   0.96140618 0.5882953  0.97635669 0.10063405]
#  [0.86215141 0.57003509 0.55914391 0.50556968 0.26071945 0.12046889
#   0.57313504 0.16680503 0.73122984 0.17947451]
#  [0.0345857  0.46303854 0.50762869 0.12743789 0.33432719 0.24607599
#   0.55150674 0.96252621 0.87748049 0.40879019]
#  [0.99682298 0.29074179 0.83878697 0.78522602 0.15130404 0.28022624
#   0.60648621 0.32017617 0.03731947 0.8862945 ]]

# %%
## Paso 3: definimos una funcion para oscurecer el color base dependiendo del valor

# %%
def darken_color(value, base_color):
    
   

    """
    value: float entre 0 (sin cambio) y 1 (oscuro)
    base_color: array RGB (valores entre 0 y 1)
    """
    darkened =  (1-value)*base_color
    return mcolors.to_hex(darkened)

# %%
color_matrix = np.vectorize(lambda v: darken_color(v, base_rgb))(data)
color_matrix
# Out:
# array([['#07000f', '#070010', '#37027a', '#2c0263', '#4a03a5', '#200148',
#         '#0a0017', '#420394', '#0d011c', '#14012c'],
#        ['#37027b', '#05000a', '#39027f', '#170134', '#3e038c', '#38027c',
#         '#190138', '#31026d', '#5904c6', '#0f0121'],
#        ['#270257', '#4e03af', '#0c001a', '#200147', '#110127', '#0d011d',
#         '#350277', '#000000', '#4f03b0', '#2a025d'],
#        ['#32026f', '#5504bd', '#3e038a', '#120128', '#2b0260', '#0e011e',
#         '#4c03a9', '#1b013d', '#270257', '#4a03a7'],
#        ['#260255', '#5704c2', '#5a04c9', '#45039b', '#010002', '#210149',
#         '#1c013e', '#270257', '#22014c', '#3e038a'],
#        ['#23014d', '#2c0262', '#040009', '#5504bf', '#170133', '#5204b7',
#         '#090015', '#390280', '#040009', '#170134'],
#        ['#13012b', '#5404bc', '#06000e', '#070010', '#0d011e', '#37027c',
#         '#040008', '#260256', '#020005', '#5404bb'],
#        ['#0d011d', '#280259', '#29025c', '#2e0267', '#45039a', '#5204b7',
#         '#280259', '#4d03ad', '#190138', '#4c03ab'],
#        ['#5a04c9', '#320270', '#2e0266', '#5103b5', '#3e038a', '#46039d',
#         '#2a025d', '#030008', '#0b0019', '#37027b'],
#        ['#000001', '#420394', '#0f0122', '#14012d', '#4f03b1', '#430396',
#         '#250252', '#3f038d', '#5a04c8', '#0b0018']], dtype='<U7')

# %%
# Paso 4: generar imagen de colores
import matplotlib.pyplot as plt
color_matrix = np.vectorize(lambda v: darken_color(v, base_rgb))(data)

# Paso 5: convertir a imagen RGB
rgb_matrix = np.array([[mcolors.to_rgb(color) for color in row] for row in color_matrix])

# Paso 6: mostrar
plt.imshow(rgb_matrix)
plt.title("Ultra mapa de colores")
plt.colorbar()
plt.show()
